# %% [markdown]
# <a href="https://colab.research.google.com/github/Pnaveen2001/DIP/blob/main/python_and_OOPS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = int(input("Enter a year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# Enter a year: 2000
# 2000 is a leap year

# %%
num = int(input("Enter a number: "))
if num <= 1:
    print(num, "is not a prime number")
else:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
# Out:
# Enter a number: 2000
# 2000 is not a prime number

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
student1 = Student("Naveen", 21, "Computer Science")
print("Student Name:", student1.name)
print("Student Age:", student1.age)
print("Student Course:", student1.course)
# Out:
# Student Name: Naveen
# Student Age: 21
# Student Course: Computer Science

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
student1 = Student("Naveen", 21, "Computer Science")
print("Student Name:", student1.name)
print("Student Age:", student1.age)
print("Student Course:", student1.course)ye
# Out:
# Student Name: Naveen
# Student Age: 21
# Student Course: Computer Science

# %%
def even_odd(n):
  if(n%2==0):
    print("even")
  else:
    print("odd")
even_odd(5)
even_odd(20)
# Out:
# odd
# even

# %%
student = {"name": "Naveen", "age": 24, "course": "Computer Science"}
print("Original Dictionary:", student)
student["year"] = "4rd"
student["grade"] = "A"
student["city"] = "Khammam"
print("After adding 3 new key-value pairs:", student)
student.popitem()
print("After removing last inserted item:", student)
student.clear()
print("After clearing the dictionary:", student)
# Out:
# Original Dictionary: {'name': 'Naveen', 'age': 24, 'course': 'Computer Science'}
# After adding 3 new key-value pairs: {'name': 'Naveen', 'age': 24, 'course': 'Computer Science', 'year': '4rd', 'grade': 'A', 'city': 'Khammam'}
# After removing last inserted item: {'name': 'Naveen', 'age': 24, 'course': 'Computer Science', 'year': '4rd', 'grade': 'A'}
# After clearing the dictionary: {}

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a > b and a > c:
    print(a, "is the largest number")
elif b > a and b > c:
    print(b, "is the largest number")
else:
    print(c, "is the largest number")

# %%
num = int(input("Enter a number: "))
temp = num
sum = 0
n = len(str(num))
while temp > 0:
    digit = temp % 10
    sum += digit ** n
    temp //= 10
if num == sum:
    print(num, "is an Armstrong number")
else:
    print(num, "is not an Armstrong number")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2039911217.py in <cell line: 0>()
# ----> 1 num = int(input("Enter a number: "))
#       2 temp = num
#       3 sum = 0
#       4 n = len(str(num))
#       5 while temp > 0:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
    def show_all_details(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)
    def show_name(self):
        print("Name:", self.name)
student1 = Student("Naveen", 21, "Computer Science")
student2 = Student("Kiran", 22, "Information Technology")
print("Details of Student 1:")
student1.show_all_details()
student1.show_name()
print("\nDetails of Student 2:")
student2.show_all_details()
student2.show_name()
# Out:
# Details of Student 1:
# Name: Naveen
# Age: 21
# Course: Computer Science
# Name: Naveen
#
# Details of Student 2:
# Name: Kiran
# Age: 22
# Course: Information Technology
# Name: Kiran

# %%
class Grandparent:
    def display_grandparent(self):
        print("This is the Grandparent class")
class Parent(Grandparent):
    def display_parent(self):
        print("This is the Parent class")
class Child(Parent):
    def display_child(self):
        print("This is the Child class")
obj = Child()
obj.display_grandparent()
obj.display_parent()
obj.display_child()
# Out:
# This is the Grandparent class
# This is the Parent class
# This is the Child class

# %%
class A:
  def fun1(self):
    print("class A")
class B(A):
  def fun2(self):
    print("class B")
class C(B):
  def fun3(self):
    print("class C")
c = C()
c.fun3()
c.fun2()
c.fun1()
# Out:
# class C
# class B
# class A

# %%
class Mother:
    def show_mother(self):
        print("This is the Mother class")
class Father:
    def show_father(self):
        print("This is the Father class")
class Child(Mother, Father):
    def show_child(self):
        print("This is the Child class")
obj = Child()
obj.show_mother()
obj.show_father()
obj.show_child()
# Out:
# This is the Mother class
# This is the Father class
# This is the Child class

# %%
class Father:
  def drive(self):
    print("father loves to drive")
class Mother:
  def cook(self):
    print("mother loves to cook")
class Child(Father,Mother):
  def both(self):
    print("child loves both to drive a car and also to cook food")
c1 = Child()
c1.cook()
c1.drive()
c1.both()
# Out:
# mother loves to cook
# father loves to drive
# child loves both to drive a car and also to cook food
